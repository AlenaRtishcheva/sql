# %%
import pandas as pd

# %%
product_2 = pd.read_csv('Импортируемые начальные csv и xlsx HW2/product.csv')

# %%
product = pd.read_csv('Импортируемые начальные csv и xlsx HW3/product.csv')

# %%
product.equals(product_2)
# Out:
# True

# %%
customer_2 = pd.read_csv('Импортируемые начальные csv и xlsx HW2/customer.csv', sep = ';')

# %%
customer = pd.read_csv('Импортируемые начальные csv и xlsx HW3/customer.csv', sep = ';')

# %%
customer.equals(customer_2)
# Out:
# True

# %%
orders_2 = pd.read_csv('Импортируемые начальные csv и xlsx HW2/orders.csv')

# %%
orders = pd.read_csv('Импортируемые начальные csv и xlsx HW3/orders.csv')

# %%
orders.equals(orders_2)
# Out:
# True

# %%
order_items_2 = pd.read_csv('Импортируемые начальные csv и xlsx HW2/order_items.csv')

# %%
order_items = pd.read_csv('Импортируемые начальные csv и xlsx HW3/order_items.csv')

# %%
order_items.equals(order_items_2)
# Out:
# True
